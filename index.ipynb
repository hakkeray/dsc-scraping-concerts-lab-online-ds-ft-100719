# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import re
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time

# %%
r = requests.get("https://www.residentadvisor.net/events/us/losangeles")
soup = BeautifulSoup(r.content, 'html.parser')
events = soup.find('div', id="event-listing")

# %%
listings = events.findAll('li')
print(len(listings), listings[0])
# Out:
# 72 <li><p class="eventDate date"><a href="/events.aspx?ai=23&amp;v=day&amp;mn=11&amp;yr=2019&amp;dy=13"><span>Wed, 13 Nov 2019 /</span></a></p></li>

# %%
rows = []
for listing in listings:
    # set current date if it's a date
    date = listing.find('p', class_="eventDate date")
    event = listing.find('h1', class_="event-title")
    if event:
        details = event.text.split(' at ')
        event_name = details[0].strip()
        venue = details[1].strip()
        try:
            n_attendees = int(re.match("(\d*)", listing.find('p', class_="attending").text)[0])
        except:
            n_attendees = np.nan
        rows.append([event_name, venue, cur_date, n_attendees])
    elif date:
        cur_date = date.text
    else:
        continue
df = pd.DataFrame(rows)
df.head()
# Out:
#                                                    0  \
# 0  EDIT Room _ Cocodisco, Inbal Lankry and Very S...
# 1                 Clinic with Ramon Tapia (Drumcode)
# 2  Theta Grooves...A Deep/Dub/Minimal Techno Even...
# 3  Conflict of Interest with Shel—b (Rhythm Rapport)
# 4         Made to Move with Kosmik + Stacy Christine
#
#                               1                   2     3
# 0                    Bar Franca  Wed, 13 Nov 2019 /  27.0
# 1               The Sayers Club  Wed, 13 Nov 2019 /   7.0
# 2                       Gravlax  Wed, 13 Nov 2019 /   2.0
# 3                     Bar Henry  Wed, 13 Nov 2019 /   2.0
# 4  General Lee's Cocktail House  Thu, 14 Nov 2019 /  15.0

# %%
def scrape_events(events_page_url):
    r = requests.get(events_page_url)
    soup = BeautifulSoup(r.content, 'html.parser')
    listings = events.findAll('li')
    rows = []
    for listing in listings:
        #Is it a date? If so, set current date.
        date = listing.find('p', class_="eventDate date")
        event = listing.find('h1', class_="event-title")
        if event:
            details = event.text.split(' at ')
            event_name = details[0].strip()
            venue = details[1].strip()
            try:
                n_attendees = int(re.match("(\d*)", listing.find('p', class_="attending").text)[0])
            except:
                n_attendees = np.nan
            rows.append([event_name, venue, cur_date, n_attendees])
        elif date:
            cur_date = date.text
        else:
            continue
    df = pd.DataFrame(rows)
    df.head()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events/us/losangeles')
# Out:
#                                            Event_Name  \
# 0   EDIT Room _ Cocodisco, Inbal Lankry and Very S...
# 1                  Clinic with Ramon Tapia (Drumcode)
# 2   Theta Grooves...A Deep/Dub/Minimal Techno Even...
# 3   Conflict of Interest with Shel—b (Rhythm Rapport)
# 4          Made to Move with Kosmik + Stacy Christine
# 5                     L.A. 909: Chrome Mamí & Urenium
# 6                           Sylvan Esso presents With
# 7                     AFI Fest 2019 presented by Audi
# 8                           Jupiter by Stealth Nights
# 9   You Know What! 1 Year Anniversary Feat. Floog ...
# 10                  Secret Project presents Soul Clap
# 11                           Technometrik After Hours
# 12                 Le Club: Patrice Scott, Aaron Paar
# 13                                Jet Lag 005: J Cush
# 14                    Blue Hawaii Live in Los Angeles
# 15                         SBCLTR's Intimate Sessions
# 16  Far Away: Buy Music Club with Avalon Emerson &...
# 17       Underline: Miyagi with Contessa and PABLoKEY
# 18  Sound presents Eli & Fur with Anton Tumas and ...
# 19                          Sylvan Esso presents With
# 6                           Sylvan Esso presents With
# 7                     AFI Fest 2019 presented by Audi
# 8                           Jupiter by Stealth Nights
# 9   You Know What! 1 Year Anniversary Feat. Floog ...
# 10                  Secret Project presents Soul Clap
# 11                           Technometrik After Hours
# 12                 Le Club: Patrice Scott, Aaron Paar
# 13                                Jet Lag 005: J Cush
# 14                    Blue Hawaii Live in Los Angeles
# 15                         SBCLTR's Intimate Sessions
# 16  Far Away: Buy Music Club with Avalon Emerson &...
# 17       Underline: Miyagi with Contessa and PABLoKEY
# 18  Sound presents Eli & Fur with Anton Tumas and ...
# 19                          Sylvan Esso presents With
# 20                    AFI Fest 2019 presented by Audi
# 21                            Breach Christian Martin
# 22                    Streo Showcase Feat. Motoe Haus
# 23                       Red Bull presents: Tapped In
# 24      Floorplay Friday feat. King Felix / Liquorbox
# 25           Frequency presents Jerm Jerm with Mirage
# 26                                    Disclosurefest™
# 27               Into The Woods with 박혜진 Park Hye Jin
# 28           Factory 93 presents Drumcode Los Angeles
# 29                  The Xpander Project: Launch Party
# 30                  Cyclone: Afriqua (All Night Long)
# 31  Capsulem: Intimate Night with Nico Stojan (Ouï...
# 32                           Technometrik After Hours
# 33                   Soft Leather Record Label Launch
# 34  Disconic with Dave Aju, Dead-Tones, AIRS, Conn...
# 35                          In Rotation with Momentum
# 36               Le Club: Will Saul, Rocky Hill Corps
# 37  Defected USA - Los Angeles - Riva Starr, Ferre...
# 38  Moony Habits x Third Place: Bufiman & Francis ...
# 39            Amazon Uprising, a Party with a Purpose
# 40                     The Warriors: The Truce, Again
# 41                     Hector Couto & Anthony Attalla
# 42  Send»return with Jason Douglas, Gold Code, & R...
# 43                    AFI Fest 2019 presented by Audi
# 44                    Funkbox LA! Tony Touch & Mr. V.
# 45  Paradise Boom feat. Dj Lag, Mina, Late Night L...
# 46           Techlepatic Sessions 040: Anakim & Rivka
# 47               THE SPACE IN BETWEEN - Facundo Mohrr
# 48      Frequency presents Dagz Bros with Tyler.Ryyan
# 49                                    Disclosurefest™
# 50      Sunday Sanctuary presents: Jordan Strong, MLE
# 51                    AFI Fest 2019 presented by Audi
# 52                                               Rynx
# 53                    AFI Fest 2019 presented by Audi
# 54                                 Alessandro Cortini
# 55                                 Alessandro Cortini
# 56                  Space Yacht 11/19 [Closing Party]
# 57  Temple Tuesdays presents: MD, Bisharat & Jorda...
# 58           Fade L.A.: Sucia Bonita Latin Bass Night
# 59                              Space Taco Scotty Boy
#
#                                 Venue          Event_Date  Number_of_Attendees
# 0                          Bar Franca  Wed, 13 Nov 2019 /                 27.0
# 1                     The Sayers Club  Wed, 13 Nov 2019 /                  7.0
# 2                             Gravlax  Wed, 13 Nov 2019 /                  2.0
# 3                           Bar Henry  Wed, 13 Nov 2019 /                  2.0
# 4        General Lee's Cocktail House  Thu, 14 Nov 2019 /                 15.0
# 5                     Paper Tiger Bar  Thu, 14 Nov 2019 /                  6.0
# 6            Walt Disney Concert Hall  Thu, 14 Nov 2019 /                  5.0
# 7                TCL Chinese Theatres  Thu, 14 Nov 2019 /                  2.0
# 8                   TBA - Los Angeles  Thu, 14 Nov 2019 /                  1.0
# 9                   TBA - Downtown LA  Fri, 15 Nov 2019 /                 70.0
